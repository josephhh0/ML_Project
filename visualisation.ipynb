# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("preprocessed_data.csv")

# %%
data
# Out:
#       Unnamed: 0 Employment type  \
# 0              0       Full-time
# 1              1       Full-time
# 2              2       Full-time
# 3              7       Full-time
# 4              8       Full-time
# ...          ...             ...
# 5563        8253       Full-time
# 5564        8255       Full-time
# 5565        8256        Contract
# 5566        8257       Full-time
# 5567        8260       Full-time
#
#                                         Job function   Seniority level  \
# 0                             Information Technology  Mid-Senior level
# 1             Engineering and Information Technology    Not Applicable
# 2             Engineering and Information Technology    Not Applicable
# 3                                                NaN               NaN
# 4             Engineering and Information Technology    Not Applicable
# ...                                              ...               ...
# 5563                                             NaN               NaN
# 5564  Engineering, Information Technology, and Other  Mid-Senior level
# 5565                                             NaN               NaN
# 5566                          Information Technology         Associate
# 5567          Engineering and Information Technology  Mid-Senior level
#
#                   company                                        description  \
# 0             CyberCoders  job title senior data engineer location alexan...
# 1       Johnson & Johnson  ethicon johnson johnson medical device company...
# 2               Microsoft  microsofts wcb health team look senior softwar...
# 3                 Cleerly  position title staff data scientist position t...
# 4               Microsoft  passionate architecting develop mission critic...
# ...                   ...                                                ...
# 5563  VBeyond Corporation  hello greeting akash kumar vbeyond corp global...
# 5564               Oracle  oracle state local global business unit proces...
# 5565        Sky Solutions  primary skill good hand experience aws contain...
# 5566               Zillow  team sre team zillow group empowers zg product...
# 5567                Adobe  company change world digital experience adobe ...
#
#             education           location                           salary  \
# 0     bachelor degree     Alexandria, VA                              NaN
# 1     bachelor degree    Santa Clara, CA                              NaN
# 2     bachelor degree     Washington, DC  $120,000.00/yr - $189,000.00/yr
# 3     bachelor degree         Denver, CO  $130,000.00/yr - $200,000.00/yr
# 4     bachelor degree         Reston, VA  $120,000.00/yr - $189,000.00/yr
# ...               ...                ...                              ...
# 5563  bachelor degree  Mountain View, CA                              NaN
# 5564  bachelor degree      United States                              NaN
# 5565  bachelor degree        Malvern, PA                              NaN
# 5566  bachelor degree      United States                              NaN
# 5567  bachelor degree         Austin, TX                              NaN
#
#                                         title  Years_experience
# 0                        Senior Data Engineer               5.0
# 1     Principal Full Stack Software Engineer.               8.0
# 2                    Senior Software Engineer               7.0
# 3                      Staff - Data Scientist               2.0
# 4                    Senior Software Engineer               5.0
# ...                                       ...               ...
# 5563                Site Reliability Engineer               3.0
# 5564         Senior Site Reliability Engineer               5.0
# 5565                Site Reliability Engineer               0.0
# 5566         Senior Site Reliability Engineer               5.0
# 5567                Site Reliability Engineer               3.0
#
# [5568 rows x 11 columns]

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, y='Employment type', order=data['Employment type'].value_counts().index)
plt.title("Répartition des types d'emploi")
plt.xlabel("Nombre d'emplois")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Years_experience'], bins=15, color='blue')
plt.title("Distribution des années d'expérience")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Years_experience', y='Seniority level')
plt.title("Années d'expérience par niveau de seniorité")
plt.xlabel("Années d'expérience")
plt.show()
# Out:
# c:\Users\Youssef PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
plt.figure(figsize=(10, 6))
top_locations = data['location'].value_counts().head(10)
sns.barplot(x=top_locations.values, y=top_locations.index )
plt.title("Top 10 des localisations des emplois")
plt.xlabel("Nombre d'emplois")
plt.ylabel("Localisation")
plt.show()

# %%
plt.figure(figsize=(10, 6))
top_functions = data['Job function'].value_counts().head(10)
sns.barplot(x=top_functions.values, y=top_functions.index, palette='magma')
plt.title("Top 10 des fonctions les plus fréquentes")
plt.xlabel("Nombre d'emplois")
plt.ylabel("Fonction")
plt.show()
# Out:
# C:\Users\Youssef PC\AppData\Local\Temp\ipykernel_21292\4095761097.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_functions.values, y=top_functions.index, palette='magma')
# c:\Users\Youssef PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Youssef PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Youssef PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Youssef PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Youssef PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Youssef PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Youssef PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Youssef PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Youssef PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\Youssef PC\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=data, x='Seniority level', y='Years_experience', palette='muted')
plt.title("Répartition des années d'expérience par niveau de seniorité")
plt.show()
# Out:
# C:\Users\Youssef PC\AppData\Local\Temp\ipykernel_21292\2407415736.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=data, x='Seniority level', y='Years_experience', palette='muted')

# %%
top_20_companies = data['company'].value_counts().head(13)
colors = plt.cm.Blues(np.linspace(0.3, 1, 20)) 

plt.figure(figsize=(10, 7))
top_20_companies.plot.pie(autopct='%1.1f%%', startangle=90, colors=colors, legend=False)
plt.title('Percentage of the Most Repeated Companies')
plt.show()
